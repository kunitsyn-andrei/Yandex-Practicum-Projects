# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Андрей :)  Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, <b>интерпретации значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# оставил комментарий про расшифровку р-значения и добавил бонус

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# <br />        Подраздел ТОП-5 исправлен, теперь для анализа используются данные с 2014 года.
# <br />        В конце подраздела выведены диаграммы
# <br />        Дополнен вывод в конце подраздела ТОП-5
# <br />        В подраздел Жанровые предпочтния добавлен анализ на основе актульной базы и выведены диаграммы
# <br />        Общий вывод дополнен

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Андрей :) Спасибо за доработки проекта
#
# Критические ❌ комментарии остались:
#
#  + поправить выполнение подраздела ТОП-5
#
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Андрей :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# **Сборный проект - 1** Исследование рынка видеоигр
#
# Датасет представляет из себя данные о продажах игр. Нам предстоит исследовать данные и сделать выводы
#
# **Новое вступление**
#
# Предлагаемый к анализу датасет представляет из себя данные о продажах видеоигр с 1980 по 2016 год.
#
# Представленные данные: название игры, год выпуска, жанр, платформа, на которой она вышла, данные по продажам в разных регионах, оценки критиков и пользоватлей, а также возрастной рейтинг.
#
# Моя задача - изучить датасет, подготовить его к анализу, выявить присутствующие закономерности для различных платформ и различных регионов, сделать прогноз продаж на 2017 год, а также проверить истинность предложенных в Задании гипотез.
#
# Приступим!

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Подробности выполнения проекта дадут возможность вспомнить через полгода — что мы тут делали, стоит добавить

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#         Добавил чуть более подробное описание

# %% [markdown]
# ## Открытие файла и изучение общей информации

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
df = pd.read_csv("/datasets/games.csv", sep=",")

#Ознакомимся с данными
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
display(df.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        Sports     41.36
# 1         super mario bros.      nes             1985      Platform     29.08
# 2            mario kart wii      wii             2008        Racing     15.68
# 3         wii sports resort      wii             2009        Sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45          76.0         8.0          E
# 1      3.58      6.81         0.77           NaN         NaN  no_rating
# 2     12.76      3.79         3.29          82.0         8.3          E
# 3     10.93      3.28         2.95          80.0         8.0          E
# 4      8.89     10.22         1.00           NaN         NaN  no_rating
#
#    total_sales
# 0        82.54
# 1        40.24
# ...

# %%
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не помешает добавить вывод после первого знакомства с данными

# %% [markdown]
# ## Предобработка данных

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(df)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %% [markdown]
# Для начала, приведем названия столбцов к нижнему регистру

# %%
new_columns = [column.lower() for column in df.columns]
df.columns = new_columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />можно
#
#     games.columns = games.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит привести к нижнему регистру и содержимое категориальных столбцов, в т.ч. с целью поиска дубликатов

# %% [markdown]
# ### Столбец name

# %%
display(df[df['name'].isna()])
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
#Удалим эти две строки, потому что они не несут какой-либо ценной информации
df.dropna(subset=['name'], inplace=True)
df.reset_index(inplace=True,drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />верное решение

# %%
display(df['name'].value_counts())
# Out:
# Need for Speed: Most Wanted      12
# FIFA 14                           9
# LEGO Marvel Super Heroes          9
# Madden NFL 07                     9
# Ratatouille                       9
#                                  ..
# Animal Planet: Vet Collection     1
# Vitamin Z Revolution              1
# I Love Horses                     1
# Winx Club: Rockstars              1
# Doraemon                          1
# Name: name, Length: 11559, dtype: int64

# %%
display(df[df['name'] == "Madden NFL 07"])
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 241    Madden NFL 07      PS2           2006.0  Sports      3.63      0.24
# 971    Madden NFL 07     X360           2006.0  Sports      1.66      0.00
# 2034   Madden NFL 07       XB           2006.0  Sports      0.97      0.03
# 2478   Madden NFL 07      PSP              NaN  Sports      0.77      0.03
# 3228   Madden NFL 07       GC           2006.0  Sports      0.48      0.13
# 3837   Madden NFL 07      PS3           2006.0  Sports      0.47      0.00
# 4005   Madden NFL 07      Wii           2006.0  Sports      0.46      0.00
# 7371   Madden NFL 07       DS           2006.0  Sports      0.20      0.00
# 14887  Madden NFL 07      GBA           2006.0  Sports      0.02      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 241        0.01         0.61          84.0        8.2      E
# 971        0.01         0.13          80.0          6      E
# ...

# %% [markdown]
# Видим, что повторяющиеся названия - не дубликаты, а одна и та же игра, вышедшая на разных платформах.
#
# Столбец готов к дальнейшему анализу.

# %% [markdown]
# ### Столбец year_of_release

# %%
display(df[df['year_of_release'].isna()])
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16371  PDC World Championship Darts 2008      PSP              NaN
# 16403                      Freaky Flyers       GC              NaN
# 16446                          Inversion       PC              NaN
# 16456        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16520                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# По названию игры часто можно сделать вывод о дате ее выпуска. Сделаем отдельный столбец, куда поместим последнее слово в названии игры.

# %%
last_word_list = []
for game_name in df['name']:
    newlist = game_name.split(' ')
    last_word_list.append(newlist[-1])

df['last_word'] = last_word_list
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating last_word
# 0     28.96      3.77         8.45          76.0          8      E    Sports
# 1      3.58      6.81         0.77           NaN        NaN    NaN     Bros.
# 2     12.76      3.79         3.29          82.0        8.3      E       Wii
# 3     10.93      3.28         2.95          80.0          8      E    Resort
# 4      8.89     10.22         1.00           NaN        NaN    NaN      Blue

# %%
#Здесь я пытался привести столбец ['last_word'] к типу int, чтобы можно было производить операции с числами.
#У меня ничего не получилось, все время выпадала ошибка.
#Ниже представлен альтернативный вариант решения, где я последовательно фильтрую значения, а потом вручную заполняю год выпуска.

#Удаляю все символы, кроме цифр из столбца
df["last_word"] = df["last_word"].str.replace(r"[^\d\.]", "", regex=True)

x = df[df['last_word'] !='']
x = x[x['year_of_release'].isna()]
#Убираю сиквелы
x= x[x['last_word'] !='2']
x= x[x['last_word'] !='3']
x= x[x['last_word'] !='4']
x= x[x['name'] !='LEGO Harry Potter: Years 5-7']
display(x)
# Out:
#                                          name platform  year_of_release  \
# 183                           Madden NFL 2004      PS2              NaN
# 377                          FIFA Soccer 2004      PS2              NaN
# 475                wwe Smackdown vs. Raw 2006      PS2              NaN
# 1300                           Triple Play 99       PS              NaN
# 1649                      NASCAR Thunder 2003      PS2              NaN
# 2478                            Madden NFL 07      PSP              NaN
# 2491                       MLB SlugFest 20-03      PS2              NaN
# 2848                            Madden NFL 11      Wii              NaN
# 3412                            Madden NFL 06     X360              NaN
# 3485                          Madden NFL 2002       XB              NaN
# 4204                  Tiger Woods PGA Tour 07      Wii              NaN
# 4774                         NFL GameDay 2003      PS2              NaN
# ...

# %%
#Исхожу из логики, что если игра имеет в названии год, то выпущена она на год раньше.

df.loc[183, 'year_of_release'] = 2003.0
df.loc[377, 'year_of_release'] = 2003.0
df.loc[475, 'year_of_release'] = 2005.0
df.loc[1649, 'year_of_release'] = 2002.0
df.loc[2478, 'year_of_release'] = 2006.0
df.loc[2491, 'year_of_release'] = 2002.0
df.loc[2848, 'year_of_release'] = 2010.0
df.loc[3412, 'year_of_release'] = 2005.0
df.loc[3485, 'year_of_release'] = 2001.0
df.loc[4204, 'year_of_release'] = 2006.0
df.loc[4774, 'year_of_release'] = 2002.0
df.loc[5155, 'year_of_release'] = 2002.0
df.loc[6623, 'year_of_release'] = 2005.0
df.loc[8917, 'year_of_release'] = 2004.0
df.loc[9875, 'year_of_release'] = 2005.0
df.loc[13194, 'year_of_release'] = 2010.0
df.loc[13928, 'year_of_release'] = 2005.0
df.loc[14140, 'year_of_release'] = 2007.0
df.loc[15951, 'year_of_release'] = 2007.0
df.loc[16077, 'year_of_release'] = 2006.0
df.loc[16371, 'year_of_release'] = 2007.0

#Загуглил, что Lego Harry Potter вышел в 2012 году, кстати, в одной из строчек это было указано
df.loc[1608, 'year_of_release'] = 2012.0
df.loc[2131, 'year_of_release'] = 2012.0
df.loc[2272, 'year_of_release'] = 2012.0
df.loc[3080, 'year_of_release'] = 2012.0
df.loc[4817, 'year_of_release'] = 2012.0
df.loc[6475, 'year_of_release'] = 2012.0
df.loc[7209, 'year_of_release'] = 2012.0
df.loc[8058, 'year_of_release'] = 2012.0

# %%
display(df[df['year_of_release'].isna()])
# Out:
#                                               name platform  year_of_release  \
# 456                     LEGO Batman: The Videogame      Wii              NaN
# 609                                 Space Invaders     2600              NaN
# 627                                      Rock Band     X360              NaN
# 657       Frogger's Adventures: Temple of the Frog      GBA              NaN
# 677    LEGO Indiana Jones: The Original Adventures      Wii              NaN
# ...                                            ...      ...              ...
# 16346                 Agarest Senki: Re-appearance      PS3              NaN
# 16403                                Freaky Flyers       GC              NaN
# 16446                                    Inversion       PC              NaN
# 16456                  Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16520                                 Virtua Quest       GC              NaN
#
# ...

# %%
display(df[df['name'] == 'LEGO Batman: The Videogame'])
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 397    LEGO Batman: The Videogame     X360           2008.0  Action      2.04
# 456    LEGO Batman: The Videogame      Wii              NaN  Action      1.80
# 460    LEGO Batman: The Videogame       DS           2008.0  Action      1.75
# 1518   LEGO Batman: The Videogame      PS3           2008.0  Action      0.72
# 1537   LEGO Batman: The Videogame      PSP              NaN  Action      0.57
# 1552   LEGO Batman: The Videogame      PS2           2008.0  Action      0.72
# 12464  LEGO Batman: The Videogame       PC           2008.0  Action      0.02
#
#        eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 397        1.02       0.0         0.32          76.0        7.9   E10+
# 456        0.97       0.0         0.29          74.0        7.9   E10+
# 460        1.01       0.0         0.29          72.0          8   E10+
# ...

# %%
df.loc[456, 'year_of_release'] = 2008.0
df.loc[1537, 'year_of_release'] = 2008.0
display(df[df['name'] == 'LEGO Indiana Jones: The Original Adventures'])
# Out:
#                                               name platform  year_of_release  \
# 329    LEGO Indiana Jones: The Original Adventures     X360           2008.0
# 677    LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 742    LEGO Indiana Jones: The Original Adventures       DS           2008.0
# 1407   LEGO Indiana Jones: The Original Adventures      PS2           2008.0
# 1722   LEGO Indiana Jones: The Original Adventures      PSP           2008.0
# 2012   LEGO Indiana Jones: The Original Adventures      PS3           2008.0
# 13713  LEGO Indiana Jones: The Original Adventures       PC           2008.0
#
#         genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 329    Action      2.40      1.01       0.0         0.36          77.0
# 677    Action      1.51      0.61       0.0         0.21          78.0
# 742    Action      1.40      0.59       0.0         0.20          80.0
# ...

# %%
df.loc[677, 'year_of_release'] = 2008.0
display(df[df['name'] == 'Call of Duty 3'])
# Out:
#                 name platform  year_of_release    genre  na_sales  eu_sales  \
# 557   Call of Duty 3     X360           2006.0  Shooter      1.49      0.92
# 718   Call of Duty 3      Wii              NaN  Shooter      1.17      0.84
# 1254  Call of Duty 3      PS3           2006.0  Shooter      0.60      0.62
# 1914  Call of Duty 3      PS2           2006.0  Shooter      0.89      0.03
#
#       jp_sales  other_sales  critic_score user_score rating last_word
# 557       0.02         0.27          82.0        6.5      T         3
# 718       0.00         0.23          69.0        6.7      T         3
# 1254      0.03         0.26          80.0        6.9      T         3
# 1914      0.00         0.15          82.0        7.4      T         3

# %%
df.loc[718, 'year_of_release'] = 2006.0

# %%
display(df[df['year_of_release'].isna()].head(20))
# Out:
#                                           name platform  year_of_release  \
# 609                             Space Invaders     2600              NaN
# 627                                  Rock Band     X360              NaN
# 657   Frogger's Adventures: Temple of the Frog      GBA              NaN
# 804                                  Rock Band      Wii              NaN
# 1130                   Call of Duty: Black Ops       PC              NaN
# 1141                                 Rock Band      PS3              NaN
# 1300                            Triple Play 99       PS              NaN
# 1505                                 Adventure     2600              NaN
# 1584                                    Combat     2600              NaN
# 1698                 Hitman 2: Silent Assassin       XB              NaN
# 1839                                 Rock Band      PS2              NaN
# 1983               Legacy of Kain: Soul Reaver       PS              NaN
# ...

# %%
display(df[df['name'] == 'Call of Duty: Black Ops'])
df.loc[1130, 'year_of_release'] = 2010.0
# Out:
#                          name platform  year_of_release    genre  na_sales  \
# 32    Call of Duty: Black Ops     X360           2010.0  Shooter      9.70
# 41    Call of Duty: Black Ops      PS3           2010.0  Shooter      5.99
# 1130  Call of Duty: Black Ops       PC              NaN  Shooter      0.58
# 1411  Call of Duty: Black Ops      Wii           2010.0  Shooter      0.80
# 3438  Call of Duty: Black Ops       DS           2010.0  Shooter      0.50
#
#       eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 32        3.68      0.11         1.13          87.0        6.3      M
# 41        4.37      0.48         1.79          88.0        6.4      M
# 1130      0.81      0.00         0.23          81.0        5.2      M
# 1411      0.45      0.00         0.12          80.0        5.8      M
# 3438      0.04      0.00         0.04          74.0          6      T
#
#      last_word
# 32
# 41
# 1130
# 1411
# 3438

# %%
display(df[df['name'] == 'Rock Band'])
#беру данные из википедии
df.loc[627, 'year_of_release'] = 2007.0
df.loc[804, 'year_of_release'] = 2007.0
df.loc[1141, 'year_of_release'] = 2007.0
df.loc[1839, 'year_of_release'] = 2007.0
# Out:
#            name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 627   Rock Band     X360              NaN  Misc      1.93      0.33       0.0
# 804   Rock Band      Wii              NaN  Misc      1.33      0.56       0.0
# 1141  Rock Band      PS3              NaN  Misc      0.99      0.41       0.0
# 1839  Rock Band      PS2              NaN  Misc      0.71      0.06       0.0
#
#       other_sales  critic_score user_score rating last_word
# 627          0.21          92.0        8.2      T
# 804          0.20          80.0        6.3      T
# 1141         0.22          92.0        8.4      T
# 1839         0.35          82.0        6.8      T

# %%
display(df[df['year_of_release'].isna()])
# Out:
#                                            name platform  year_of_release  \
# 609                              Space Invaders     2600              NaN
# 657    Frogger's Adventures: Temple of the Frog      GBA              NaN
# 1300                             Triple Play 99       PS              NaN
# 1505                                  Adventure     2600              NaN
# 1584                                     Combat     2600              NaN
# ...                                         ...      ...              ...
# 16346              Agarest Senki: Re-appearance      PS3              NaN
# 16403                             Freaky Flyers       GC              NaN
# 16446                                 Inversion       PC              NaN
# 16456               Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16520                              Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит посмотреть на платформы, к которым относятся пропуски из колонки год выпуска игры, и с легкостью расстанешься с ними ... более 90% данных принадлежит устаревшим платформам и могут быть удалены сразу
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %% [markdown]
# В итоге у нас осталось 232 строки с пропусками вместо года выпуска. Можно было бы дальше заполнить все пропуска, пользуясь википедией, но для дальнейшего анализа это непринципиально. Удалим оставшиеся пропуски.

# %%
df = df.dropna(subset=['year_of_release']).reset_index(drop=True)
#Созданный столбец тоже больше не нужен
df = df.drop(columns=['last_word'])
#Наконец, приведем в целочисленный формат
df['year_of_release'] = df['year_of_release'].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16481 entries, 0 to 16480
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16481 non-null  object
#  1   platform         16481 non-null  object
#  2   year_of_release  16481 non-null  int64
#  3   genre            16481 non-null  object
#  4   na_sales         16481 non-null  float64
#  5   eu_sales         16481 non-null  float64
#  6   jp_sales         16481 non-null  float64
#  7   other_sales      16481 non-null  float64
#  8   critic_score     8015 non-null   float64
#  9   user_score       9872 non-null   object
#  10  rating           9800 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Стоблец готов

# %% [markdown]
# ### Столбец user_score

# %% [markdown]
# Значение tbd (to be decided, to be defined или to be determined) - означает, что оценки пока нет. Заменим на nan

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = float('nan')

# %%
df['user_score'] = df['user_score'].astype(float)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# ### Столбец total_sales

# %% [markdown]
# Выполним задание и добавим столбец с общемировыми продажами

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16481 entries, 0 to 16480
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16481 non-null  object
#  1   platform         16481 non-null  object
#  2   year_of_release  16481 non-null  int64
#  3   genre            16481 non-null  object
#  4   na_sales         16481 non-null  float64
#  5   eu_sales         16481 non-null  float64
#  6   jp_sales         16481 non-null  float64
#  7   other_sales      16481 non-null  float64
#  8   critic_score     8015 non-null   float64
#  9   user_score       7490 non-null   float64
#  10  rating           9800 non-null   object
#  11  total_sales      16481 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# **Вывод**
#
# В процессе предобработки были сделаны следующие действия:
#
# Названия столцов приведены к змеиному регистру
#
# Пропуски в столбце 'year_of_release" заменены, где это возможно. Столбец приведен в целочисленный формат
#
# Удалены строки с пропусками в столбце "name"
#
# Столбец "user_score" переведен в формат float
#
# Добавлен столбец с показателем общемировых продаж
#
# Всего удалено 234 строки, что составляет 1.4% от первоначального количества
#
# **Данные готовы для дальнейшего анализа**

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные, стоит внимательно взглянуть на содержимое и предложить чем заполнить пропуски, возможно это поможет найти необычные различия в поведении клиентов, допом можно подумать над сокращением количества категорий
#
# Т.к. записи с пропусками не учитываются при группировке данных, мы не сможем выявить реальный портрет клиента

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Датасет не проверен на наличие простых дубликатов
#
# __Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого столбцов к нижнему регистру
#
# В выборке есть 2 строчки неполных дубликатов, если останется время стоит их поискать
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# ### Работа над ошибками

# %%
#Составим словарь имя-рейтинг name_rating и заполним в соостветствии с ним пропуски в столбце rating
#Таким образом, мы заполним информацию по рейтингу для тех игр, рейтинг которых известен для других платформ.

name_rating = df.set_index("name")['rating'].dropna().to_dict()

def fill_rating(x):
    if pd.isna(x['rating']):
        return name_rating.get(x['name'])
    return x['rating']

df['rating'] = df.apply(fill_rating, axis=1)

df.info()
#Удалось заполнить 418 строк
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16481 entries, 0 to 16480
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16481 non-null  object
#  1   platform         16481 non-null  object
#  2   year_of_release  16481 non-null  int64
#  3   genre            16481 non-null  object
#  4   na_sales         16481 non-null  float64
#  5   eu_sales         16481 non-null  float64
#  6   jp_sales         16481 non-null  float64
#  7   other_sales      16481 non-null  float64
#  8   critic_score     8015 non-null   float64
#  9   user_score       7490 non-null   float64
#  10  rating           10218 non-null  object
#  11  total_sales      16481 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
#Для оставшихся пропусков назначим значение no_rating
df['rating'] = df['rating'].fillna('no_rating')
display(df['rating'].value_counts())
# Рейтинги EC, K-A, RP и АО для анализа не пригодятся. 
# Удалять их я не буду, просто когда буду делать анализ, буду работать только со значимыми рейтингами.
# Out:
# no_rating    6263
# E            4088
# T            3033
# M            1623
# E10+         1458
# EC             10
# K-A             4
# RP              1
# AO              1
# Name: rating, dtype: int64

# %%
df_duplicates_check = df
df_duplicates_check['name'] = df_duplicates_check['name'].str.lower()
df_duplicates_check['platform'] = df_duplicates_check['platform'].str.lower()
duplicates = df_duplicates_check[df_duplicates_check[['name', 'platform']].duplicated(keep=False)]
duplicates
# Out:
#                               name platform  year_of_release   genre  \
# 604                  madden nfl 13      ps3             2012  Sports
# 1187   need for speed: most wanted     x360             2012  Racing
# 1585   need for speed: most wanted     x360             2005  Racing
# 5909   need for speed: most wanted       pc             2005  Racing
# 11565  need for speed: most wanted       pc             2012  Racing
# 16005                madden nfl 13      ps3             2012  Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 604        2.11      0.22      0.00         0.23          83.0         5.5
# 1187       0.62      0.78      0.01         0.15          83.0         8.5
# 1585       1.00      0.13      0.02         0.10          83.0         8.5
# 5909       0.02      0.23      0.00         0.04          82.0         8.5
# 11565      0.00      0.06      0.00         0.02          82.0         8.5
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />У двух пар игр разные года выпуска, это второе или третье издание обновленной игры

# %%
#Нашлось три пары дубликатов
#Удалим позиции с меньшими показателями продаж - то есть с индексами 1585, 11565, 16005
#Насколько я помню, ниже в проекте к индесам я больше не обращаюсь, поэтому индексы сброшу.
df = df.drop(index = [1585, 11565, 16005]).reset_index(drop=True)

# %%
#Исправим выброс у приставки Nintendo DS
df_ds = df[df['platform'] == 'ds']
display(df_ds[df_ds['year_of_release'] < 2004])
# Out:
#                                       name platform  year_of_release   genre  \
# 15737  strongest tokyo university shogi ds       ds             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15737       0.0       0.0      0.02          0.0           NaN         NaN
#
#           rating  total_sales
# 15737  no_rating         0.02

# %%
# В интернете дата релиза - май 2010
df.loc[15736, 'year_of_release'] = 2010

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Сколько выходило игр в каждом году

# %%
plt.figure(figsize=(15,10))
plt.plot(df.groupby('year_of_release')['name'].count(), label='Релизы')
plt.ylabel('Количество релизов в год')
plt.show()

# %% [markdown]
# Из графика видно, что резкий рост релизов наблюдается с 1994, пик был достигнут в 2009-2010 годах, когда количество релизов составляло около 1400 игр в год. После этого наступает двукратный спад, и количество релизов после 2012 года выходит на плато, стабилизировавшись на показателе около 600 релизов в год.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# ### Анализ продаж по платформам

# %%
platform_sales_pivot_table = pd.pivot_table(df, index=['platform'], values='total_sales', aggfunc='sum')
platform_sales_pivot_table = platform_sales_pivot_table.sort_values('total_sales',ascending=False).reset_index()
platform_sales_pivot_table
# Out:
#    platform  total_sales
# 0       ps2      1249.17
# 1      x360       964.07
# 2       ps3       933.87
# 3       wii       903.32
# 4        ds       803.45
# 5        ps       727.58
# 6       ps4       314.14
# 7       gba       312.88
# 8       psp       292.07
# 9       3ds       258.21
# 10       pc       257.52
# 11       gb       254.43
# 12       xb       252.66
# 13      nes       251.05
# 14      n64       218.01
# 15     snes       200.04
# 16       gc       196.73
# 17     xone       159.32
# 18     2600        86.48
# 19     wiiu        82.19
# 20      psv        53.81
# 21      sat        33.59
# 22      gen        28.35
# 23       dc        15.95
# 24      scd         1.86
# 25       ng         1.44
# 26       ws         1.42
# 27     tg16         0.16
# 28      3do         0.10
# 29       gg         0.04
# 30     pcfx         0.03

# %%
popular_platforms = platform_sales_pivot_table.loc[0:10, 'platform'].values
plt.figure(figsize=(18, 8))
plt.grid()
plt.title('Продажи игр на популярных платформах в разные годы')
for i in range(0,len(popular_platforms)):
    platform  = df.query('platform == @popular_platforms[@i]').groupby('year_of_release')['total_sales'].sum()
    platform.plot(x=platform.index, y=platform.values, label=popular_platforms[i], marker = 'o', grid=True);    
plt.ylabel('Объём продаж')
plt.legend()
plt.show()

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#         Выброс удален

# %%
platform_life = df.pivot_table(index='platform', values='year_of_release', aggfunc=['min', 'max']).reset_index()
platform_life.set_axis(['platform', 'first_year', 'last_year'], axis='columns', inplace=True)
platform_life['life_span'] = platform_life.last_year - platform_life.first_year + 1 
display(platform_life)
display(platform_life['life_span'].describe())
# Out:
#    platform  first_year  last_year  life_span
# 0      2600        1980       1989         10
# 1       3do        1994       1995          2
# 2       3ds        2011       2016          6
# 3        dc        1998       2008         11
# 4        ds        1985       2013         29
# 5        gb        1988       2001         14
# 6       gba        2000       2007          8
# 7        gc        2001       2007          7
# 8       gen        1990       1994          5
# 9        gg        1992       1992          1
# 10      n64        1996       2002          7
# 11      nes        1983       1994         12
# 12       ng        1993       1996          4
# 13       pc        1985       2016         32
# 14     pcfx        1996       1996          1
# 15       ps        1994       2003         10
# 16      ps2        2000       2011         12
# 17      ps3        2006       2016         11
# 18      ps4        2013       2016          4
# ...

# %%
platform_life.query('platform in @popular_platforms')['life_span'].describe()
# Out:
# count    11.000000
# mean     13.363636
# std       8.891262
# min       4.000000
# 25%       9.000000
# 50%      11.000000
# 75%      12.000000
# max      32.000000
# Name: life_span, dtype: float64

# %% [markdown]
# Исходя из представленных выше графиков и таблиц можно сделать следующие выводы:
#
# Средний срок жизни платформы  7-9 лет. У популярных платформ - 9-12 лет.
# Это не касается ПК, который является "вечной" платформой. Однако, если верить данным, ПК находится лишь на 11 месте по доле продаж среди других платформ.
#
# Актуальным периодом по продажам считаю время с 2012 по 2016 год - именно в 2012 году рынок стабилизировался после резкого падения и вышел на плато, соответственно данные за эти 5 лет должны быть сопоставимы, а также этих данных должно быть достаточно, чтобы сделать прогноз на 2017 год.

# %% [markdown]
# **Новый вывод**
# Для того, чтобы сделать анализ продаж, рассмотрим данные с 2014 года. За последние три года не успели смениться актульные на данный момент платформы, следовательно, можно предположить, что актуальными будут именно те платформы, которые актуальны за за последние три года.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#         Актуальным периодом по продажам считаю время с 2012 по 2016 год - именно в 2012 году рынок стабилизировался после резкого падения и вышел на плато, соответственно данные за эти 5 лет должны быть сопоставимы, а также этих данных должно быть достаточно, чтобы сделать прогноз на 2017 год.

# %% [markdown]
# ### Актуальные платформы и прогноз на 2017 год

# %%
#Отфильтруем все платформы, на которых не вышло ни одной игры в 2016 годы
actual_platforms = platform_life.query('last_year > 2015')['platform'].values
display(platform_life.query('last_year > 2015'))
# Out:
#    platform  first_year  last_year  life_span
# 2       3ds        2011       2016          6
# 13       pc        1985       2016         32
# 17      ps3        2006       2016         11
# 18      ps4        2013       2016          4
# 20      psv        2011       2016          6
# 25      wii        2006       2016         11
# 26     wiiu        2012       2016          5
# 28     x360        2005       2016         12
# 30     xone        2013       2016          4

# %%
df_actual = df.query('year_of_release > 2011')
platform_sales = df_actual.pivot_table(index='platform', values='total_sales', columns = 'year_of_release', aggfunc = 'sum', fill_value=0, margins=True).reset_index()
platform_sales = platform_sales.query('platform in @actual_platforms')

actual_heatmap = platform_sales.sort_values(by=2016, ascending=False)[['platform', 2012, 2013, 2014, 2015, 2016]].set_index('platform')
plt.figure(figsize=(10, 8))
sns.heatmap(actual_heatmap, annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# Как мы видим из тепловой карты, можно ожидать сколько-нибудь больших показателей продаж можно в четырех платформах - PS4, XOne, 3DS, PC. Остальные платформы добирают продажи "по инерции". Поскольку в описании к заданию сказано, что данные за 2016 год неполные, точно сказать будет ли снижение, например, у PS4, нельзя. Но в целом, тренд на снижение доходов от релизов налицо.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#         Отдельно изучу продажи с 2014 года

# %%
prognosis = df[df['year_of_release'] > 2013]
platform_sales_pivot_table_new = pd.pivot_table(prognosis, index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum').reset_index()
platform_sales_pivot_table_new.set_axis(['platform', 'year_of_release', 'total_sales'], axis='columns', inplace=True)
sns.barplot(data=platform_sales_pivot_table_new, x="platform", y="total_sales", hue = 'year_of_release')
# Out:
# <AxesSubplot:xlabel='platform', ylabel='total_sales'>

# %% [markdown]
# **Из графика видно, что ожидать больших продаж мы можем на платформах XBOX One и PS4. Также непложие показатели могут быть у PC и Nintendo DS.**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %%
top4 = ["ps4", "xone", "pc", "3ds"]
(df_actual.query('platform in @top4')[['platform', 'name', 'total_sales']]
 .boxplot(column='total_sales', by='platform', figsize=(10,10))
)
plt.xlabel('Платформа')
plt.ylabel('Количество проданных копий, млн')
plt.title('Диаграммы размаха по продажам на актуальных платформах')
plt.ylim(0, 5)
plt.show()

# %% [markdown]
# Вывод можно сделать следующий: игры на консоли стоят в разы дороже, чем на ПК. С другой стороны, если рассматривать представленные годы, то покупать игры на ПК было вовсе не обязательно. На эти годы пришелся расцвет пришелся расцвет пиратства.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит ограничивать перечень платформ из актуального периода для оценки прибыльности платформ__
#
# диаграмму размаха перерисовать на актуальной выборке с полным перечнем платформ

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#         Добавлю диаграмму размаха для других платформ

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит показать на диаграмме размаха все платформы, которые входят в актуальный период выборки df_actual, чтобы у нас не оставалось сомнений в выборе самых перспективных платформ
#
# Эти платформы нас уже не интересуют, главная задача проекта другая
#
#         p = {ax1:'ps', ax2:'ps2', ax3:'ps3', ax4:'ds', ax5:'wii', ax6:'x360', ax7:'psp', ax8:'gba'}

# %%
popular_platforms
#построим "ящик с усами для других платформ, которые есть в этом списке"
# Out:
# array(['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps', 'ps4', 'gba', 'psp',
#        '3ds', 'pc'], dtype=object)

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(nrows=1, ncols=8, figsize=(16, 12))
fig.autofmt_xdate();

p = {ax1:'ps', ax2:'ps2', ax3:'ps3', ax4:'ds', ax5:'wii', ax6:'x360', ax7:'psp', ax8:'gba'}
for ax in [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]:
    sales = df.query('platform==@p[@ax] and total_sales<1.5')['total_sales']
    ax.boxplot(sales)
    ax.grid()
    ax.set_title(p[ax])

fig.autofmt_xdate()

# %% [markdown]
# Вывод - стационарные приставки с продажи одной игры заработывают заметно больше, чем портативные.

# %% [markdown]
# ### Связь оценок критиков и продаж

# %%
PS4_table = df.query('platform == "ps4"')
PS4_table = PS4_table.loc[:,['total_sales', 'critic_score', 'user_score']]
PS4_table.head()
# Out:
#     total_sales  critic_score  user_score
# 31        14.63           NaN         NaN
# 42        12.62          97.0         8.3
# 77         8.58          82.0         4.3
# 87         7.98           NaN         NaN
# 92         7.66          83.0         5.7

# %%
PS4_table.corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.406568   -0.031957
# critic_score     0.406568      1.000000    0.557654
# user_score      -0.031957      0.557654    1.000000

# %%
sns.set(rc={'figure.figsize':(12,10)})
sns.scatterplot(data=PS4_table, x="total_sales", y="critic_score")
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='critic_score'>

# %% [markdown]
# Если игра хорошо продается, то у нее высокие оценки критиков. Обратное не столь очевидно. Есть много примеров, где высокая оценка критиков не гарантировала успеха в продажах.

# %%
sns.scatterplot(data=PS4_table, x="total_sales", y="user_score")
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='user_score'>

# %% [markdown]
# Основное отличие от предыдущего графика - много достаточно успешных коммерческих проектов получили у пользователей посредственные оценки.

# %%
sns.scatterplot(data=PS4_table, x="critic_score", y="user_score")
# Out:
# <AxesSubplot:xlabel='critic_score', ylabel='user_score'>

# %% [markdown]
# Между оценками критиков и оценками пользователей сильная прямая корреляция. Хотя есть и исключения.

# %% [markdown]
# **ВЫВОД** : Можно отметить достаточно сильную прямую корреляцию успехов в продажах и высоких оценок у критиков.
# Между оценками пользователей и продажами есть небольшая обратная корреляция, можно связать это с тем, что пользователи имеют тенденцию выставлять негативную оценку проектам, которые были успешны на рынке, но игнорировали желания фанбазы.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При подобной величине коэффициента не важно какой у него знак, плюс или минус
#
#         есть небольшая обратная корреляция
#
#
# [Шкала Чедока. Объяснит отличие слабой корреляции от умеренной и высокой.](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит выполнить исследование зависимости продаж от оценок пользователей и критиков по платформам конкурентам — рассмотреть в этом разделе отдельно две-три платформы
#
#         ps3, xone
#
# Выводы, сделанные на основе расчетов по нескольким платформам выглядят "весомей" и убедительней

# %% [markdown]
# #### Сравнеие связи на примере других платформ

# %%
#для сравнения возьмем три другие платформы из переменной top4
new_dict = {}
for a in top4:
    new_dict[a] = df.query('platform==@a')[['total_sales', 'critic_score', 'user_score']].dropna().reset_index(drop=True)

# %%
i=0
corr = pd.DataFrame(columns=['platform','critic_sales','user_sales'])
for pl_name in new_dict.keys():
    corr.loc[i, 'platform'] = pl_name
    corr.loc[i, 'critic_sale'] = new_dict[pl_name]['total_sales'].corr(new_dict[pl_name]['critic_score'])
    corr.loc[i, 'user_sale'] = new_dict[pl_name]['total_sales'].corr(new_dict[pl_name]['user_score'])
    i+=1
corr
# Out:
#   platform critic_sales user_sales  critic_sale  user_sale
# 0      ps4          NaN        NaN     0.405895  -0.033625
# 1     xone          NaN        NaN     0.410422  -0.094003
# 2       pc          NaN        NaN     0.258014   0.000439
# 3      3ds          NaN        NaN     0.338426   0.232444

# %%
plt.figure(figsize=(16, 9))
plt.grid()
plt.title('Зависимости продаж от отзывов Критиков на разных платформах')
i=0
for p in corr['platform']:
    xc = new_dict[p]['critic_score'].to_list()
    yc = new_dict[p]['total_sales'].to_list()
    plt.scatter(xc, yc, label=p, alpha=0.8);
    i+=1 
plt.ylim(0,6)
plt.grid()
plt.xlabel('Отзывы Критиков')    
plt.ylabel('Объём продаж')
plt.legend()
plt.show();

plt.figure(figsize=(16, 9))
plt.grid()
plt.title('Зависимости продаж от отзывов Пользователей на разных платформах')
i=0
for p in corr['platform']:
    xc = new_dict[p]['user_score'].to_list()
    yc = new_dict[p]['total_sales'].to_list()
    plt.scatter(xc, yc, label=p, alpha=0.8);
    i+=1 
plt.ylim(0,4)
plt.grid()
plt.xlabel('Отзывы Пользователей')    
plt.ylabel('Объём продаж')
plt.legend()
plt.show();

# %% [markdown]
# **Вывод**
#
# По цифрам видно, что у PS4,  XBOX One и ПК очень похожи значения корреляции, как у критиков, так и у пользователей.
# У Nintendo DS - корреляция с мнением критиков такая же, как и у остальных платформ, однако владельцы этой японской приставки склонны доверять отзывам пользователей - корреляция здесь значительно больше, чем у других платформ, но все равно не настолько сильная.
#
# В целом, вывод подверждает заключения из предыдущей части - отзывы критиков коррелируют с маркетинговым успехом, отзывы пользователей - нет.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит разделять подобные диаграммы, читать и исследовать будет легче

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# ### Оценка игр по жанрам

# %%
genre = df.groupby('genre')['name'].count().sort_values(ascending=False)
genre
# Out:
# genre
# Action          3317
# Sports          2322
# Misc            1725
# Role-Playing    1481
# Shooter         1298
# Adventure       1293
# Racing          1227
# Platform         878
# Simulation       857
# Fighting         838
# Strategy         673
# Puzzle           569
# Name: name, dtype: int64

# %%
genre_table = df.pivot_table(index='genre', values='name', aggfunc=['count']).reset_index()
genre_table.set_axis(['genre', 'games_count'], axis='columns', inplace=True)
genre_table = genre_table.sort_values(by = 'games_count', ascending = False)
sns.barplot(data=genre_table, x="genre", y="games_count")
# Out:
# <AxesSubplot:xlabel='genre', ylabel='games_count'>

# %%
#Теперь проанализируем количество продаж по жанрам
genre_sales = df.groupby('genre')['total_sales'].sum().sort_values(ascending=False)
genre_sales
# Out:
# genre
# Action          1727.85
# Sports          1323.77
# Shooter         1045.22
# Role-Playing     931.08
# Platform         825.55
# Misc             797.59
# Racing           723.47
# Fighting         445.66
# Simulation       387.96
# Puzzle           239.89
# Adventure        233.33
# Strategy         172.57
# Name: total_sales, dtype: float64

# %%
genre_sales_table = df.pivot_table(index='genre', values='total_sales', aggfunc=['sum']).reset_index()
genre_sales_table.set_axis(['genre', 'sales'], axis='columns', inplace=True)
genre_sales_table = genre_sales_table.sort_values(by = 'sales', ascending = False)
sns.barplot(data=genre_sales_table, x="genre", y="sales")
# Out:
# <AxesSubplot:xlabel='genre', ylabel='sales'>

# %% [markdown]
# Если сравнивать два графика, то можно увидеть, что в по размеру продаж игры жанра экшн не настолько критично обгоняют все остальные жанры, как по простому количеству игр. Также можно отметить, что шутеры выходят на 3 место по прибыли. Еще заметный рост у платформеров - кто бы мог подумать, что платформеры настолько прибыльные? А, я совсем забыл, что у нас данные с 1980 года.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Для исследования стоит использовать выборку с актуальным периодом

# %%
genre_boxplot = prognosis[['genre', 'name', 'total_sales']] .boxplot(column='total_sales', by='genre', figsize=(16,10))

# %%
genre_boxplot = prognosis[['genre', 'name', 'total_sales']] .boxplot(column='total_sales', by='genre', figsize=(16,10))
genre_boxplot.set(ylim=(0,8))
# Out:
# [(0.0, 8.0)]

# %% [markdown]
# **Вывод: Если рассматривать удельные доходы отдельно взятой игры, то на первое место выходят шутеры - медиана по продажам лежит намного выше остальных жанров.
# На втором месте по удельному доходу от игры - спотривные игры. За ними следуют  платформеры. Показатели жанра экшн здесь не сильно выделяются на общем фоне.
# Меньше всего удельного зароботка у игр в жанрах Adventure, Strategy и Puzzle.**

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Визуализация категориальных данных](https://pyprog.pro/sns/sns_7_categorical_data.html?)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %% [markdown]
# ## Портрет пользователя для каждого региона

# %% [markdown]
# ### Топ-5 платформ в каждом регионе

# %%
#Найдем топ5 платформ по продажам в Северной Америке
na_platform_table = pd.pivot_table(prognosis, index='platform', values='na_sales',
                                        aggfunc='sum').sort_values('na_sales', ascending=False).reset_index()
na_platform_table.set_axis(['platform', 'na_sales'], axis='columns', inplace=True)
top5na = na_platform_table[0:5]['platform'].values
top5na
# Out:
# array(['ps4', 'xone', 'x360', '3ds', 'ps3'], dtype=object)

# %%
#Определим долю рынка для каждой консоли
#Доля рынка не является актульной на 2017 год, она нужна нам просто для составления "портрета" пользователя
na_sum = na_platform_table['na_sales'].sum()
for i in range (len(na_platform_table['na_sales'])):
    if na_platform_table.loc[i, 'platform'] in top5na:
        print('Доля от всех продаж игр в Северной Америке с 2014 года для консоли:',na_platform_table.loc[i, 'platform'], 'составляет', "{0:.0%}".format(na_platform_table.loc[i,'na_sales']/na_sum))
# Out:
# Доля от всех продаж игр в Северной Америке с 2014 года для консоли: ps4 составляет 35%
# Доля от всех продаж игр в Северной Америке с 2014 года для консоли: xone составляет 29%
# Доля от всех продаж игр в Северной Америке с 2014 года для консоли: x360 составляет 10%
# Доля от всех продаж игр в Северной Америке с 2014 года для консоли: 3ds составляет 8%
# Доля от всех продаж игр в Северной Америке с 2014 года для консоли: ps3 составляет 8%

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#         Построю графики для наглядного визуального отображения цифр

# %%
#График делаю очень коряво, но результат важнее
percent_list_na = [35,29,10,8,8]
percent_list_na.append(100 - sum(percent_list_na))
top5na = top5na.tolist()
top5na.append('other_platforms')
d = {'top_platforms': top5na, 'percentage': percent_list_na}
na_plot_table = pd.DataFrame(data=d)
sns.barplot(data = na_plot_table, x = 'top_platforms', y = 'percentage')
# Out:
# <AxesSubplot:xlabel='top_platforms', ylabel='percentage'>

# %%
#Для большей достоверности построим также секционную диаграмму (т.н. pie chart)
plt.pie(data = na_plot_table, x = 'percentage', labels = 'top_platforms')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd2f64ad070>,
# ...
#  [Text(0.4993895680663529, 0.9801071672559597, 'ps4'),
#   Text(-1.0994572142025187, 0.03455190498419851, 'xone'),
#   Text(-0.4049370950921533, -1.0227540999762987, 'x360'),
#   Text(0.20611935297230619, -1.0805159935559852, '3ds'),
#   Text(0.7011663061946445, -0.8475646353272169, 'ps3'),
#   Text(1.0461621345079046, -0.3399187966586506, 'other_platforms')])

# %%
eu_platform_table = pd.pivot_table(prognosis, index='platform', values='eu_sales',
                                        aggfunc='sum').sort_values('eu_sales', ascending=False).reset_index()
eu_platform_table.set_axis(['platform', 'eu_sales'], axis='columns', inplace=True)
top5eu = eu_platform_table[0:5]['platform'].values
top5eu
# Out:
# array(['ps4', 'xone', 'ps3', 'pc', '3ds'], dtype=object)

# %%
eu_sum = eu_platform_table['eu_sales'].sum()
for i in range (len(eu_platform_table['eu_sales'])):
    if eu_platform_table.loc[i, 'platform'] in top5eu:
        print('Доля от всех продаж игр в Европе с 2014 года для консоли:',eu_platform_table.loc[i, 'platform'], 'составляет', "{0:.0%}".format(eu_platform_table.loc[i,'eu_sales']/eu_sum))
# Out:
# Доля от всех продаж игр в Европе с 2014 года для консоли: ps4 составляет 48%
# Доля от всех продаж игр в Европе с 2014 года для консоли: xone составляет 17%
# Доля от всех продаж игр в Европе с 2014 года для консоли: ps3 составляет 9%
# Доля от всех продаж игр в Европе с 2014 года для консоли: pc составляет 7%
# Доля от всех продаж игр в Европе с 2014 года для консоли: 3ds составляет 6%

# %%
percent_list_eu = [48,17,9,7,6]
percent_list_eu.append(100 - sum(percent_list_eu))
top5eu = top5eu.tolist()
top5eu.append('other_platforms')
d_eu = {'top_platforms': top5eu, 'percentage': percent_list_eu}
eu_plot_table = pd.DataFrame(data=d_eu)
sns.barplot(data = eu_plot_table, x = 'top_platforms', y = 'percentage')
# Out:
# <AxesSubplot:xlabel='top_platforms', ylabel='percentage'>

# %%
plt.pie(data = eu_plot_table, x = 'percentage', labels = 'top_platforms')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd2f63ecaf0>,
# ...
#  [Text(0.0690696084852792, 1.0978293989430645, 'ps4'),
#   Text(-1.0095301152477212, -0.4368626173156991, 'xone'),
#   Text(-0.37261175878219355, -1.0349688291041623, 'ps3'),
#   Text(0.17207787594174198, -1.086457180293535, 'pc'),
#   Text(0.5894094409985068, -0.9287607392982479, '3ds'),
#   Text(1.0095300641201765, -0.43686273546448473, 'other_platforms')])

# %%
jp_platform_table = pd.pivot_table(prognosis, index='platform', values='jp_sales',
                                        aggfunc='sum').sort_values('jp_sales', ascending=False).reset_index()
jp_platform_table.set_axis(['platform', 'jp_sales'], axis='columns', inplace=True)
top5jp = jp_platform_table[0:5]['platform'].values
top5jp
# Out:
# array(['3ds', 'ps4', 'psv', 'ps3', 'wiiu'], dtype=object)

# %%
jp_sum = jp_platform_table['jp_sales'].sum()
for i in range (len(jp_platform_table['jp_sales'])):
    if jp_platform_table.loc[i, 'platform'] in top5jp:
        print('Доля от всех продаж игр в Японии с 2014 года для консоли:',jp_platform_table.loc[i, 'platform'], 'составляет', "{0:.0%}".format(jp_platform_table.loc[i,'jp_sales']/jp_sum))
# Out:
# Доля от всех продаж игр в Японии с 2014 года для консоли: 3ds составляет 48%
# Доля от всех продаж игр в Японии с 2014 года для консоли: ps4 составляет 16%
# Доля от всех продаж игр в Японии с 2014 года для консоли: psv составляет 16%
# Доля от всех продаж игр в Японии с 2014 года для консоли: ps3 составляет 12%
# Доля от всех продаж игр в Японии с 2014 года для консоли: wiiu составляет 8%

# %%
percent_list_jp = [48,16,16,12,8]
percent_list_jp.append(100 - sum(percent_list_jp))
top5jp = top5jp.tolist()
top5jp.append('other_platforms')
d_jp = {'top_platforms': top5jp, 'percentage': percent_list_jp}
jp_plot_table = pd.DataFrame(data=d_jp)
sns.barplot(data = jp_plot_table, x = 'top_platforms', y = 'percentage')
# Out:
# <AxesSubplot:xlabel='top_platforms', ylabel='percentage'>

# %%
plt.pie(data = jp_plot_table, x = 'percentage', labels = 'top_platforms')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd2f63365e0>,
# ...
#  [Text(0.0690696084852792, 1.0978293989430645, '3ds'),
#   Text(-1.0227541663239421, -0.40493692751713595, 'ps4'),
#   Text(-0.20611955530271972, -1.0805159549593932, 'psv'),
#   Text(0.7011662863559625, -0.8475646517391985, 'ps3'),
#   Text(1.0654414403595847, -0.27355901952685396, 'wiiu'),
#   Text(1.0999999999999892, -1.544841498309619e-07, 'other_platforms')])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(16, 7))
fig.autofmt_xdate()

ax1.set_title('Северная Америка')
ax1.pie(data = na_plot_table, x = 'percentage', labels = 'top_platforms',
        shadow=True,startangle=0)  
ax1.axis('equal')  

ax2.set_title('Европа')
ax2.pie(data = eu_plot_table, x = 'percentage', labels = 'top_platforms',
        shadow=True,startangle=0) 
ax2.axis('equal')

ax3.set_title('Япония')
ax3.pie(data = jp_plot_table, x = 'percentage', labels = 'top_platforms',
        shadow=True,startangle=0) 
ax3.axis('equal')
# Out:
# (-1.113885616036924,
#  1.1006612198112822,
#  -1.1152395940227005,
#  1.1153841075852347)

# %% [markdown]
# **ВЫВОД** Рынки Европы и Северной Америки достаточно похожи - разница лишь в том, что в Америке чуть лучше себя показывает X-BOX 360.
#
# Рынок Японии кардинально отличается. Там большую долю занимают платформы от компании Nintendo - Nintendo DS, 3DS и Super Nintendo.

# %% [markdown]
# **НОВЫЙ ВЫВОД** Если рассматривать период с 2014 по конец 2016 года, то опять можно сказать, что рынки Европы и Америки очень похожи -  с той небольшой лишь разницей, что в Америке чуть больше доля XBOX One . И там, и там лидирует ps4.
#
# В Японии - на первом месте Nintendo 3ds. Современный рынок японии - полностью делят следующие платформы - 3ds, Playstation 4, psv, PS3 и Wii

# %% [markdown]
# ### Жанровые предпочтения по регионам

# %%
na_genre_table = pd.pivot_table(df, index='genre', values='na_sales', aggfunc='sum').sort_values('na_sales', ascending=False)
na_genre_table
# Out:
#               na_sales
# genre
# Action          869.28
# Sports          680.31
# Shooter         586.58
# Platform        444.44
# Misc            404.53
# Racing          356.46
# Role-Playing    330.04
# Fighting        222.08
# Simulation      180.40
# Puzzle          121.13
# Adventure       101.52
# Strategy         67.75

# %%
eu_genre_table = pd.pivot_table(df, index='genre', values='eu_sales', aggfunc='sum').sort_values('eu_sales', ascending=False)
eu_genre_table
# Out:
#               eu_sales
# genre
# Action          514.89
# Sports          374.64
# Shooter         316.17
# Racing          234.80
# Misc            211.96
# Platform        199.39
# Role-Playing    188.24
# Simulation      113.35
# Fighting        100.02
# Adventure        63.20
# Puzzle           49.78
# Strategy         44.79

# %%
jp_genre_table = pd.pivot_table(df, index='genre', values='jp_sales', aggfunc='sum').sort_values('jp_sales', ascending=False)
jp_genre_table
# Out:
#               jp_sales
# genre
# Role-Playing    353.39
# Action          160.14
# Sports          134.99
# Platform        130.71
# Misc            107.02
# Fighting         87.28
# Simulation       63.64
# Puzzle           56.68
# Racing           56.65
# Adventure        52.24
# Strategy         49.30
# Shooter          38.68

# %% [markdown]
# **ВЫВОД** Снова получаем схожие картины в США и Европе - в лидерах экшны и спортивные игры. В Японии на первом месте  - РПГ, также заметно лучше показывают себя платформеры.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> дополнил данный подраздел исследованием данных по актуальной базе

# %%
na_genre_table_2014 = pd.pivot_table(prognosis, index='genre', values='na_sales', aggfunc='sum').sort_values('na_sales', ascending=False).reset_index()
na_genre_table_2014.set_axis(['genre', 'na_sales'], axis='columns', inplace=True)
na_genre_table_2014
# Out:
#            genre  na_sales
# 0        Shooter     79.02
# 1         Action     72.53
# 2         Sports     46.13
# 3   Role-Playing     33.47
# 4           Misc     15.05
# 5       Fighting     12.43
# 6         Racing      8.74
# 7       Platform      6.79
# 8      Adventure      5.64
# 9     Simulation      2.63
# 10      Strategy      0.98
# 11        Puzzle      0.65

# %%
eu_genre_table_2014 = pd.pivot_table(prognosis, index='genre', values='eu_sales', aggfunc='sum').sort_values('eu_sales', ascending=False).reset_index()
eu_genre_table_2014.set_axis(['genre', 'eu_sales'], axis='columns', inplace=True)
eu_genre_table_2014
# Out:
#            genre  eu_sales
# 0         Action     74.68
# 1        Shooter     65.52
# 2         Sports     45.73
# 3   Role-Playing     28.17
# 4         Racing     14.13
# 5           Misc     12.86
# 6     Simulation      7.30
# 7       Platform      6.80
# 8       Fighting      6.69
# 9      Adventure      6.49
# 10      Strategy      1.79
# 11        Puzzle      0.52

# %%
jp_genre_table_2014 = pd.pivot_table(prognosis, index='genre', values='jp_sales', aggfunc='sum').sort_values('jp_sales', ascending=False).reset_index()
jp_genre_table_2014.set_axis(['genre', 'jp_sales'], axis='columns', inplace=True)
jp_genre_table_2014
# Out:
#            genre  jp_sales
# 0   Role-Playing     31.16
# 1         Action     29.58
# 2       Fighting      6.37
# 3           Misc      5.61
# 4        Shooter      4.87
# 5      Adventure      3.60
# 6         Sports      3.26
# 7       Platform      2.69
# 8     Simulation      2.31
# 9         Racing      1.76
# 10      Strategy      0.95
# 11        Puzzle      0.93

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(16, 7))
fig.autofmt_xdate()

ax1.set_title('Северная Америка')
ax1.pie(data = na_genre_table_2014, x = 'na_sales', labels = 'genre',
        shadow=True,startangle=0)  
ax1.axis('equal')  

ax2.set_title('Европа')
ax2.pie(data = eu_genre_table_2014, x = 'eu_sales', labels = 'genre',
        shadow=True,startangle=0) 
ax2.axis('equal')

ax3.set_title('Япония')
ax3.pie(data = jp_genre_table_2014, x = 'jp_sales', labels = 'genre',
        shadow=True,startangle=0) 
ax3.axis('equal')
# Out:
# (-1.1062034718709242,
#  1.100295405410619,
#  -1.1004705846969287,
#  1.1012149555336928)

# %% [markdown]
# **НОВЫЙ ВЫВОД**
# Снова подтверждается тезис о том, что рынки Северной Америки и Европы похожи. Разница с данными с 1980 года, что в последние три года шутеры почти обогнали экшны по прибыли в данных регионах.
# В Японии по-прежнему на первом месте РПГ

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов рассчитаны, молодец, значительное влияние на портрет оказывает период с 1980 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne
#
# https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/?ysclid=l4q3l4q0p8940570437
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html?highlight=append#pandas.DataFrame.append

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#         Графики для ТОП-5 я построил. Выбрал актуальный период - с 2014 и позднее. Сделал на вскякий случай двух видов. Сделал, как умею на данный момент. Subplots и двухуровневый заголовок делать пока не умею.
#                 Категорию "другие" добавил, отобразил на графиках.

# %%
df.head(3)
# Out:
#                 name platform  year_of_release     genre  na_sales  eu_sales  \
# 0         wii sports      wii             2006    Sports     41.36     28.96
# 1  super mario bros.      nes             1985  Platform     29.08      3.58
# 2     mario kart wii      wii             2008    Racing     15.68     12.76
#
#    jp_sales  other_sales  critic_score  user_score     rating  total_sales
# 0      3.77         8.45          76.0         8.0          E        82.54
# 1      6.81         0.77           NaN         NaN  no_rating        40.24
# 2      3.79         3.29          82.0         8.3          E        35.52

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для ТОП-5 выбран датасет df, который содержит данные с 1980 года, стоит поменять на актуальный срез данных

# %%
# check

# пример из ссылки

# данные для линий

x = np.linspace(0, 5, 11)
y = x**2

# строим графики

plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')  #  Магия
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оставляю примеры из ссылок, как расположить графики
#
# и пример какой вид графиков лучше
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# ### Влияние рейтинга ESRB в разных регионах

# %%
esrb = df.groupby('rating')['na_sales', 'eu_sales', 'jp_sales'].sum().sort_values(by='na_sales', ascending=False).reset_index()
esrb
# Out:
# /tmp/ipykernel_30/1040384728.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   esrb = df.groupby('rating')['na_sales', 'eu_sales', 'jp_sales'].sum().sort_values(by='na_sales', ascending=False).reset_index()
#       rating  na_sales  eu_sales  jp_sales
# 0          E   1332.94    730.74    210.19
# 1  no_rating   1122.32    547.87    800.29
# 2          T    778.37    441.43    163.14
# 3          M    761.30    495.86     67.37
# 4       E10+    363.70    194.29     48.24
# 5        K-A      2.59      0.29      1.49
# 6         EC      2.04      0.11      0.00
# 7         AO      1.26      0.61      0.00
# 8         RP      0.00      0.03      0.00

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     Удалю  все рейтинги, не нужные для анализа

# %%
esrb = esrb[esrb['na_sales'] >10]
esrb['percent_of_na_sales'] = esrb['na_sales']/esrb['na_sales'].sum()
esrb['percent_of_eu_sales'] = esrb['eu_sales']/esrb['eu_sales'].sum()
esrb['percent_of_jp_sales'] = esrb['jp_sales']/esrb['jp_sales'].sum()
esrb
# Out:
# /tmp/ipykernel_30/1327270967.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esrb['percent_of_na_sales'] = esrb['na_sales']/esrb['na_sales'].sum()
# /tmp/ipykernel_30/1327270967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esrb['percent_of_eu_sales'] = esrb['eu_sales']/esrb['eu_sales'].sum()
# /tmp/ipykernel_30/1327270967.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# Построим pie chart для каждого региона

# %%
plt.pie(data = esrb, x = 'percent_of_na_sales', labels = 'rating')
plt.show()

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в3</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     ([<matplotlib.patches.Wedge at 0x7f173881de80>,
#       <matplotlib.patches.Wedge at 0x7f173882a3d0>,
#       <matplotlib.patches.Wedge at 0x7f173882a850>,
#       <matplotlib.patches.Wedge at 0x7f173882acd0>,
#       <matplotlib.patches.Wedge at 0x7f17387b9190>],
#      [Text(0.6301958615101101, 0.9015837044531863, 'E'),
#       Text(-1.0083271683401276, 0.4396320297557723, 'no_rating'),
#       Text(-0.6319362382726603, -0.9003646987514557, 'T'),
#       Text(0.5252219694240607, -0.9665101566120821, 'M'),
#       Text(1.062419663742625, -0.28506921631948884, 'E10+')])
#
# plt.pie(data = esrb, x = 'percent_of_na_sales', labels = 'rating');

# %%
plt.pie(data = esrb, x = 'percent_of_eu_sales', labels = 'rating')
# Out:
# /tmp/ipykernel_30/1875906830.py:1: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(data = esrb, x = 'percent_of_eu_sales', labels = 'rating')
# ([<matplotlib.patches.Wedge at 0x7fd2f60670a0>,
# ...
#  [Text(0.6376193757690729, 0.8963490010279802, 'E'),
#   Text(-0.9532427267760895, 0.5489337882190218, 'no_rating'),
#   Text(-0.791968165628423, -0.763404496077375, 'T'),
#   Text(0.446488526519588, -1.0053099003224664, 'M'),
#   Text(1.0649136618762103, -0.2756064091225037, 'E10+')])

# %%
plt.pie(data = esrb, x = 'percent_of_jp_sales', labels = 'rating')
plt.show()

# %% [markdown]
# **В Европе и Америке** в целом картины схожи. Большинство людей во всех регионах играют в игры с рейтингом E - everyone.
#
# **В Японии преобладают игры без рейтинга ESRB. Рейтинг ESRB предназначен для рецензирования игр на территории Северной Америки. Поэтому в Японии так популярны игры вовсе без регйтинга - судя по всему, это игры, созданные в Японии**
#
# В Японии чуть больший процент к общему количеству игр показывают игры с рейтингов T - для тинейджеров.
#
# В Европе больше всех процент тех, кто играет в игры с самым суровым рейтингом M - mature.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Заполнение пропусков в рейтинге позволило определить отличия региональных рынков, молодец

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1

# %% [markdown]
# Нулевая гипотеза, поставленная в задаче, звучит следующим образом - "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые".
#
# **Соответственно, альтернативная гипотеза будет звучать следующим образом:
# Средние пользовательские рейтинги платформ Xbox One и PC различаются**
#
# Значение alpha пример в 5 процентов - как нас учили.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
alpha = 0.05

results = st.ttest_ind(
    df[(df.platform == "xone") & (df.user_score.notna())]['user_score'], 
    df[(df.platform == "pc") & (df.user_score.notna())]['user_score']
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.429690848596658e-05
# Отвергаем нулевую гипотезу

# %% [markdown]
# Получилось очень маленькое значение p-value, становится интересно. Построим гистограммы, изучим распределение подробнее.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(df[(df.platform == "xone") & (df.user_score.notna())]['user_score'], bins=10, density=True, alpha=0.5)
ax.hist(df[(df.platform == "pc") & (df.user_score.notna())]['user_score'], bins=10, density=True, alpha=0.5)
plt.show()

# %% [markdown]
# Видно, что у игр на ПК рейтинг сильно скошен. Высоких оценок действительно больше на ПК.

# %% [markdown]
# Проведем еще один эксперимент - только в этот раз возьмем релизы начиная с 2013 года - года выпуска первой игры на XBOX One

# %%
results = st.ttest_ind(
    df[(df.platform == "xone") & (df.user_score.notna()) & (df.year_of_release > 2012)]['user_score'], 
    df[(df.platform == "pc") & (df.user_score.notna()) & (df.year_of_release > 2012)]['user_score']
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# В этот раз нулевую гипотезу отвергнуть не удалось! Посмотрим на гисторгаммы.

# %% [markdown]
# **Значение p-value в 0.14012658403611647, обозначает, что вероятность появления экстремального значения составлеят более 14%.
# В нашем случае - это вероятность того, что оценки пользователей будут различаться.
# Гипотеза отвергается, потому что значение p-value выше 5%, которые мы выбрали в качестве порога статистической значимости.
# Порог значимости выбирается произвольно, чаще всего принято устанавливать статистическую значимость в рамках 5 процентов**

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.14012658403611647
#
#         пропущено одно важное слово

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(df[(df.platform == "xone") & (df.user_score.notna()) & (df.year_of_release > 2012)]['user_score'], bins=10, density=True, alpha=0.5)
ax.hist(df[(df.platform == "pc") & (df.user_score.notna()) & (df.year_of_release > 2012)]['user_score'], bins=10, density=True, alpha=0.5)
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Средних оценок на ПК стало гораздо больше - и теперь смело можно сказать, что рейтинги игр распределены одинаково.
# Какой вывод из этого можно сделать - в ранние годы оценки игр на ПК были выше и соответственно, отличались от оценок игр на XOne. Иными словами - "раньше было лучше".
#
# Учитывая то, что игры на XOne начали выходить, начиная с 2013 года, логично сравнивать их оценки с оценками игр на ПК за аналогичный период.
# В таком случае отвергнуть нулевую гипотезу не удастся.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы не сформулированы

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что посмотрел на дату начала сбора оценок по новой платформе

# %% [markdown]
# ### Гипотеза 2

# %% [markdown]
# **Нулевая гипотеза: Средние пользовательские рейтинги жанров Action и Sports равны;**
#
# **Альтернативная гипотеза - Средние пользовательские рейтинги жанров Action и Sports различаются**

# %%
rating_action = df.query('genre == "Action"')['user_score'].dropna()
rating_sports = df.query('genre == "Sports"')['user_score'].dropna()
results = st.ttest_ind(
    rating_action, 
    rating_sports
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.06864268272765858
# Не получилось отвергнуть нулевую гипотезу

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(rating_action, bins=10, density=True, alpha=0.5)
ax.hist(rating_sports, bins=10, density=True, alpha=0.5)
plt.show()

# %% [markdown]
# Если смотреть на всю выборку - то можно уверенно сказать, что рейтинги экшнов и спортивных игр совпадают.
# Теперь проделаем тот же трюк, что в прошлый раз и посмотрим, что происходит, если отфильтровать игры 2012 года и ранее

# %%
rating_action = df[(df.genre == "Action") & (df.user_score.notna()) & (df.year_of_release > 2012)]['user_score']
rating_sports = df[(df.genre == "Sports") & (df.user_score.notna()) & (df.year_of_release > 2012)]['user_score']
results = st.ttest_ind(
    rating_action, 
    rating_sports
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(rating_action, bins=10, density=True, alpha=0.5)
ax.hist(rating_sports, bins=10, density=True, alpha=0.5)
plt.show()

# %% [markdown]
# Вывод можно сделать такой - в последние годы резко упал пользовательский рейтинг спортивных игр. Неудивительно - ведь год от года они предлагают один и тот же геймплей!
#
# Отвергнуть или принять нулевую гипотезу - зависит от выборки. Если мы берем игры, вышедшие после 2012 - то гипотезу отвергаем.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы не сформулированы

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# вывод по предобработке см. в разделе
#
# **По реультатам анализа можно сделать следующий вывод:**

# %% [markdown]
# Представленные данные дают представление о периоде расцвета и заката старой схемы продажи видеоигр, когда 90 процентов прибыли разработчики получили с непосредственной продажи игры в момент ее релиза.
#
# Резкий рост по количеству релизов игр наступает в 1994 году. Пик релизов наступает в 2010 и уже в 2012 релизы падают в 2 раза и до 2016 держатся примерно на одном уровне.
# Можно предположить, что падение в 2011-2012 годах обусловлено думя факторами:
#
# 1.Некоторые компании стали продавать свои игры через аффилированные магазины или лаунчеры. Примеры: Battle Net, Epic Games Store, Play Station Store и другие.
#
# 2.Переход массовой аудитории в сессионные игры и игры-сервисы (DOTA2, CS:GO, World of Tanks и другие) - теперь разработчики получают большинство прибыли не от продажи игр (зачастую игры распространяются бесплатно) - а от продаж внутри игры. Следовательно, мы не можем судить об успешности игры по показателю продаж.
#
# 3.Время разработки игр увеличилось, следовательно, и релизов на единицу времени стало меньше.
#
# Так или иначе, это уже другие гипотезы, проверить которые без привлечения исследования дополнительных данных невозможно, иными словами, как говорит Леонид Каневский, - "это уже совсем другая история".
#
# Средний срок существоания платформы - 7-9 лет. Для популярных платформ этот срок составляет до 13 лет.
# ПК - исключение и "вечная" платформа.
#
# Между высокими отзывами критиков и продажами игр - есть прямая корреляция. Однако, не у всех игр с высокими оценками - хорошие продажи. Но - у всех игр с хорошими продажами - высокая оценка критиков.
#
# Немного другая ситуация с оценками пользователей. Их не столь интересует коммерческий успех проекта - и мы видим, что многим успешным коммерческим проектам они ставят низкую оценку. Как следствие - практически нулевая корреляция между продажами и оценкой пользователей.
#
# Самые популярные жанры в Европе и Америке - Экшн и спортивные игры. В Японии - РПГ.
# **Если говорить о современных играх (начиная с 2014 года) - в Америке и Европе наибольшую популярность имеют экшн и шутеры. В Я понии по-прежнему популярны РПГ.
#
# **Если оценивать жанры игр по доходности, то больше всего денег в сумме заработали экшны, но если оценивать удельную доходность игры - то больше всего зарабатывют шутеры и спортивные игры, медиана по доходности у игр этих жанров выше чем у игр жанра экшн**
#
# Самые популярные платформы в Европе и Америке - ХВОХ и PlayStation, а в Японии - консоли от Nintendo.
# **Если говорить о последних трех годах - лидерство в Европе и Америке занимают PS4, XBOX One. В Японии на первом месте - Nintendo 3DS**
#
# Значимого влияния рейтинга ESRB на продажи не видно. **В Японии у большинства игр отсутствует маркировка ESRB. Вероятно, игры, выпущенные в Японии, не получают маркировку ESRB**
#
# Что касается проверки гипотез - ключевое значение имеют годы выборки. Если мы смотрим всю выборку, начиная с 1980 года, то первую гипотезу отвегаем, а вторую - нет. Если же мы берем выборку игр после 2012 года, то результаты прямо противоположные.
#
# Причины тому - для первой гипотезы - у старых игр на ПК заметно более высокая оценка, чем у современных.
# Для второй - резкое падение пользовательского рейтинга спортивных игр за последние пять лет, доступных для анализа.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно добавить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках
#
# мы формируем рекомендацию для интернет магазина, для продажи или наполнения ассортимента

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить подробностей во вступление
#  + обработка пропусков в столбце рейтингов ESRB
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + выполнить проверку на дублирование записей
#  + самое важное — переопределить актуальный период
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + добавить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + оценить прибыльность жанров на диаграмме размаха
#  + построить графики в ТОП-5 и пересмотреть раздел рейтингов
#  + в разделе проверки гипотез добавить Н0 и Н1, плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#
#  + добавить подробностей во вступление
#     - я постарался сделать вступление более живым и информативным
#  + обработка пропусков в столбце рейтингов ESRB
#     - добавил подпункт "работа над ошибками" в конце раздела "Предподготовка данных", где заполнил рейтинг для тех игр, у которых рейтинг определен на других платформах
#     - для всех игр без рейтинга определил значение рейтинга как  no_rating
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#     - для анализа достаточно оставить 4 категории (5 с учетом no_rating).
#     - На этапе предподготвки оставил все как есть, см. анализ по рейтингу
#  + выполнить проверку на дублирование записей
#     - Найдено три пары дубликатов. см. работа над ошибками в конце раздела предподготовка
#     - устранен выброс для Nintendo DS
#  + самое важное — переопределить актуальный период
#     - вывод об актуальном периоде дополнен
#     - тепловую карту с 2012 года менять не стал, на ней лучше видны тенденции
#     - построил новый барплот для всех продаж, начиная с 2014 года
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#     - построил дополнительную диаграмму размаха для 8 дополнительных платформ (до этого было 4). Всего - 12 ящиков с усами.
#  + добавить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#     - добавлен раздел 3.4.1. В качестве объектов для сравнения - популярные на 2016 год приставки.
#  + оценить прибыльность жанров на диаграмме размаха
#     - добавлены графики двух разных масштабов, вывод дополнен
#  + построить графики в ТОП-5 и пересмотреть раздел рейтингов
#     - два вида графиков добавлено в топ-5
#     - раздел рейтингов пересмотрен, добавлены графики
#  + в разделе проверки гипотез добавить Н0 и Н1, плюс можно более подробно расшифровать значение p_value
#     - Добавил формулировки Н0 и Н1, расшифровал значение p-value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#     - промежуточные выводы дополнены (старые выводы я сохранил на всякий случай)
#     - итоговый вывод дополнен
#
#
# Благодарю за все комментарии.
# Комментарии по поводу широких строк обязательно буду учитывать в последующих проектах
#
# Большая дружеская просьба - когда закончишь ревью проекта, особенно в том случае, если нужна будет доработка, скинь, пожалуйста, мне в телеграм +79258617009, что ревью окончено. Это очень мне поможет уложиться в срок, потому что жесткий дедлайн у меня уже завтра - 5 марта. Очень хочу продолжить обучение!

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />К сожалению, подобная опция не предусмотрена в наших правилах

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
    labels_c=sales.platform
    colours = {'Wii':'C0', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'steelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'C14', '2600':'C15', 'PSP':'C16', 
               'XOne':'C17',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 1985

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2012

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2014

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ,
#
# плюс, можно увидеть как гиганты отрасли поглотили рынок :) с 1985-2016 гг.

# %%
# check
# круги в ряд
fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle('Обзор рынка платформ (портрет покупателя)', fontsize = 30, fontweight='bold')

x_year = 2015

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])
