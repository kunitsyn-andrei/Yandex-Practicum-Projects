# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет еще раз!\
# Все критические замечания устранены, проект принят!
#
# Желаю тебе успехов во всех будущих начинаниях! 🙂
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Андрей, привет!
#
# Меня зовут Сергей Кулешин, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом. Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div style="background:#e5e5e5; color:#000; padding:10px">
#     <b>Общее впечатление о проекте</b>
#
# Ты верно разобрался в причинах убыточности бизнеса. Видно, что ты умеешь писать и применять функции, это здорово облегчает работу аналитика. Однако есть моменты, которые требуют твоего внимания и доработки.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
#   ❌ Каждый аналитический проект должен начинаться с введения, которое содержит: название, краткое описание проекта, цели и задачи, описание исходных данных, план (декомпозицию) анализа данных и т.д. Добавь пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#    Добавил описание проекта ниже
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Описание проекта есть.
# </div>

# %% [markdown]
# <font size=6>Анализ бизнес-показателей приложения</font>
#
# Предмет исследования - данные об использовании развлекательного приложения Procrastinate Pro+. Наша задача - выявить причины убытков компании. Вложенные в рекламу деньги за последнее время не окупились. Мы должны найти факторы, отрицательно влияющие на доходность приложения.
#
# Для анализа предоставлены  логи с данными о посещениях приложения пользователями, зарегистрировавшимися в период с 1 мая 2019 года по 27 октября того же года,
# выгрузка их покупок за этот период, а также затрат компании-разработчика на проведених рекламных кампаний. В рамках исследования будет изучено, как люди пользуются продуктом, когда они начинают покупать,
# сколько денег приносит каждый клиент, какие устройства он использует для работы с приложением, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Прямые ссылки на скачивание файлов лучше убрать. По правилам Яндекса проекты нельзя выкладывать с прямыми ссылками к данным.
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
sessions = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# %%
display(sessions.info(), orders.info(), costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# Предобработка данных

# %%
#Переименование столбцов
sessions.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']
orders.columns = ['user_id', 'event_dt','revenue']
costs.columns = ['dt', 'channel','costs']

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Когда колонок много, а переименовываем не все лучше использовать метод `rename()` - чтобы избежать в реальных проектах проблемы, когда последовательность в колонках может поменяться.
#
# Или использовать что-то типа такого:
# ```python
# sessions.columns = sessions.columns.str.lower().str.replace(' ', '_')
# ```
# </div>

# %%
#изменение типа данных
sessions['session_start'] = pd.to_datetime(sessions['session_start'])
sessions['session_end'] = pd.to_datetime(sessions['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
#Проверка на дубликаты
display(sessions.duplicated().sum())
display(orders.duplicated().sum())
display(costs.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
#Проверка на наличие пропусков
display(sessions.isna().sum())
display(orders.isna().sum())
display(costs.isna().sum())
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# Предоставленные для анализа данные состоят из трех таблиц.
#
# В таблице sessions мы сохранили данные о посещениях пользователей. Таблица состоит из 309901 строк.
#
# В таблице orders мы записали данные о покупках. Всего было совершено 40212 покупок.
#
# Таблица costs будет хранить данные о рекламных компаниях. Всего - 1800 записей.
#
# Столбцы с данными о времени приведены к корректному типу данных. Дубликатов и пропусков в таблицах не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Данные получены и подготовлены к анализу! Хорошо, что заметил неверный формат даты и поменял.
# </div>

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# Подготовим функции, необходимые нам для дальнейшего анализа.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, costs):

   # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Отличные функции!
# </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %%
profiles = get_profiles(sessions, orders, costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Не выводи на показ весь датафрейм, при больших объемах можно подвесить ноутбук. Используй head(), tail() или sample().
# </div>

# %%
#найдем максимальную и минимальную дату привелечения пользователей 
min_date = costs['dt'].min()
max_date = costs['dt'].max()
display(min_date, max_date)
# Out:
# datetime.date(2019, 5, 1)
# datetime.date(2019, 10, 27)

# %% [markdown]
# Вывод: Мы получили таблицу profiles, которая хранит данные о 150008 уникальных пользователях.
#
# Самой ранней датой привлечения пользователей является 1 мая 2019 года.
# Самоя поздняя запись о привлечении пользователей сделана 27 октября 2019 года.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Замечательно, у нас есть даты!
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Стоит сказать, что они совпадают с заданием.
# </div>

# %% [markdown]
# #### Анализ пользователей с дифференциацией по странам

# %%
# Построим круговые диаграммы, которые показывают распределение пользователей по странам

country = profiles.groupby('region').agg({'user_id': 'count', 'payer': 'sum'})\
.sort_values(by='user_id', ascending=False)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 7))
fig.autofmt_xdate()

ax1.set_title('Доля всех пользователей по странам')
ax1.pie(country['user_id'], labels=country.index, autopct='%1.1f%%',
        shadow=True,startangle=0)  
ax1.axis('equal')  

ax2.set_title('Доля платящих пользователей по странам')
ax2.pie(country['payer'], labels=country.index, autopct='%1.1f%%',
        shadow=True,startangle=0) 
ax2.axis('equal')
plt.show()

# %%
country['percentage'] = country['payer']/country['user_id']*100
country['not_payer'] = country['user_id'] - country['payer']
country
# Out:
#                user_id  payer  percentage  not_payer
# region
# United States   100002   6902    6.901862      93100
# UK               17575    700    3.982930      16875
# France           17450    663    3.799427      16787
# Germany          14981    616    4.111875      14365

# %%
fig, ax = plt.subplots(figsize=(15, 5))
country[['not_payer', 'payer']].plot(kind='barh', stacked=True, ax=ax)
plt.title('Количество пользователей по странам')
plt.show()

# %% [markdown]
# Вывод: Подавляющее количество пользователей приложения - из США. США лидирует не только в абсолютных показателях, но и в относительных - США показывают наилучшее соотношение платящих пользователей к неплатящим 6.9%, тогда как у трех других стран этот показатель находится в районе 4%.

# %% [markdown]
# #### Анализ пользователей с дифференциацией по устройствам

# %%
device = profiles.groupby('device').agg({'user_id': 'count', 'payer': 'sum'})\
.sort_values(by='user_id', ascending=False)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 7))
fig.autofmt_xdate()

ax1.set_title('Устройства всех пользователей')
ax1.pie(device['user_id'], labels=device.index, autopct='%1.1f%%',
        shadow=True,startangle=0)  
ax1.axis('equal')  

ax2.set_title('Устройства платящих пользователей')
ax2.pie(device['payer'], labels=device.index, autopct='%1.1f%%',
        shadow=True,startangle=0) 
ax2.axis('equal')
plt.show()

# %%
device['percentage_of_paying_users'] = device['payer']/device['user_id']*100
device['not_payer'] = device['user_id'] - device['payer']
device = device.sort_values(by = 'percentage_of_paying_users', ascending = False)
device
# Out:
#          user_id  payer  percentage_of_paying_users  not_payer
# device
# Mac        30042   1912                    6.364423      28130
# iPhone     54479   3382                    6.207897      51097
# Android    35032   2050                    5.851793      32982
# PC         30455   1537                    5.046790      28918

# %%
fig, ax = plt.subplots(figsize=(15, 5))
device[['not_payer', 'payer']].plot(kind='barh', stacked=True, ax=ax)
plt.title('Количество пользователей с разбивкой по устройствам')
plt.xlabel('Количество пользователей')
plt.ylabel('Устройство')
plt.show()

# %% [markdown]
# Вывод: В лидерах по количеству пользователей - IPhone (неудивительно - ведь большая часть пользователей приложения из США).
# Если смотреть на соотношение в конверсии пользователей, то все устройства показывают приблизительно одинаковый результат. Лучшие цифры у Mac - 6.36%. В аутсайдерах - пользователи ПК - 5.05%.

# %% [markdown]
# #### Каналы привлечения пользователей

# %%
channel = profiles.groupby('channel').agg({'user_id': 'count', 'payer': 'sum'})\
.sort_values(by='user_id', ascending=False)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 7))
fig.autofmt_xdate()

ax1.set_title('Каналы привлечения пользователей')
ax1.pie(channel['user_id'], labels=channel.index, autopct='%1.1f%%',
        shadow=True,startangle=0)  
ax1.axis('equal')  

ax2.set_title('Каналы привлечения платящих пользователей')
ax2.pie(channel['payer'], labels=channel.index, autopct='%1.1f%%',
        shadow=True,startangle=0) 
ax2.axis('equal')
plt.show()

# %%
channel['percentage_of_paying_users'] = channel['payer']/channel['user_id']*100
channel['not_payer'] = channel['user_id'] - channel['payer']
channel = channel.sort_values(by = 'percentage_of_paying_users', ascending = False)
channel
# Out:
#                     user_id  payer  percentage_of_paying_users  not_payer
# channel
# FaceBoom              29144   3557                   12.204914      25587
# AdNonSense             3880    440                   11.340206       3440
# lambdaMediaAds         2149    225                   10.469986       1924
# TipTop                19561   1878                    9.600736      17683
# RocketSuperAds         4448    352                    7.913669       4096
# WahooNetBanner         8553    453                    5.296387       8100
# YRabbit                4312    165                    3.826531       4147
# MediaTornado           4364    156                    3.574702       4208
# LeapBob                8553    262                    3.063253       8291
# OppleCreativeMedia     8605    233                    2.707728       8372
# organic               56439   1160                    2.055316      55279

# %%
channel = channel.sort_values(by = 'user_id')
fig, ax = plt.subplots(figsize=(15, 10))
channel[['not_payer', 'payer']].plot(kind='barh', stacked=True, ax=ax)
plt.title('Количество пользоватлей с разбивкой по каналам привлечения')
plt.xlabel('Канал привлечения')
plt.ylabel('Устройство')
plt.show()

# %% [markdown]
# Вывод: 37.6% пользователей приложения - органические (привлеченные без затрат).
#
# Из рекламных каналов по количеству привлеченных пользователей лидируют FaceBoom и TipTop. Эти два канала выделяются на общем фоне. Через все другие рекламные каналы (без учета "органических" пользоватлей) в сумме привлечено лишь 30% процентов от их общего числа.
#
# Через FaceBoom привлечено 19.4% от общего числа пользователей и 40.1% от количества платящих пользователей.
# Через TipTop привлечено 13% от общего числа пользователей и 21.1% от количества платящих пользователей.
#
# FaceBoom показывает лучшую долю платящих пользователей - 12.2%.
# Самая низкая конверсия у "органических" пользователей - 2.05%

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ С платящими определились. Здорово, что добавлена визуализация!
# </div>

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %%
print('Общая сумма затрат на рекламу:', costs.costs.sum().round())
# Out:
# Общая сумма затрат на рекламу: 105497.0

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Общие затраты посчитали.
# </div>

# %%
costs_grouped = costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False).reset_index()
costs_grouped
# Out:
#               channel     costs
# 0              TipTop  54751.30
# 1            FaceBoom  32445.60
# 2      WahooNetBanner   5151.00
# 3          AdNonSense   3911.25
# 4  OppleCreativeMedia   2151.25
# 5      RocketSuperAds   1833.00
# 6             LeapBob   1797.60
# 7      lambdaMediaAds   1557.60
# 8        MediaTornado    954.48
# 9             YRabbit    944.22

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data=costs_grouped, x="channel", y="costs")
plt.title('Общее количество затрат на привлечение пользователей с разбивкой по каналам привлечения')
plt.ylabel('Затраты')
plt.xlabel('Канал привлечения пользователей')
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ График недооформленный, надо вывести название графика и подписать оси. Чтобы убрать технические надписи вроде:`<AxesSubplot:xlabel='channel', ylabel='costs'>` в конце вывода графика напиши: `plt.show()` По всем остальным графикам тоже.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   plt.show() добавлено по всему проекту
#
#   Также добавлены plt.title(), plt.xlabel(), plt.ylabel(), где необходимо.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %% [markdown]
# Вывод: Подавляющая часть затрат уходит на привлечение пользователей через TipTop и FaceBoom.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  На популярные каналы тратится больше.
#
# </div>
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Стоит вывести еще процент затрат каждого канала от общей суммы, так будет понятней общая картина.
# </div>

# %% [markdown]
# #### Динамика изменения затрат на привлечение пользователей

# %%
costs.pivot_table(
    index='dt',
    columns='channel',  
    values='costs',  
    aggfunc='sum',  
).plot(figsize=(20, 15), grid=True)

plt.title('Изменение трат по времени')
plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.show()

# %%
# В задании сказано -  сделать визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику
# и сделать это на одном графике
# если я правильно понимаю задание - то решением является график выше
# ниже на всякий случай я делаю общий график динамики изменения расходов во времени по всем источникам
# с разбивкой по месяцам (первый график) и по неделям (второй график)
costs['dt'] = pd.to_datetime(costs['dt'])
costs['month'] = costs['dt'].dt.month
costs['week'] = costs['dt'].dt.isocalendar().week
costs_monthly = costs.groupby('month').agg({'costs': 'sum'}).reset_index()
costs_weekly = costs.groupby('week').agg({'costs': 'sum'}).reset_index()
sns.lineplot(data=costs_monthly, x="month", y="costs")
plt.show()

# %%
sns.lineplot(data=costs_weekly, x="week", y="costs")
plt.show()

# %% [markdown]
# Вывод: Графики показывают рост расходов на привлечение пользователей с течением времени.
#
# Рост затрат обусловлен увеличением платежей по основным каналам привлечения пользователей - TipTop (рост затра на привлечение в шесть раз) и Faceboom (рост затрат в 2.5 раза).

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ В задании  просят: Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) `по каждому источнику`. Т.е. получается два графика с разбивкой по неделям и месяцам, которые лучше разместить рядом, используя, например subplot()
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Я построил графики ниже. За ось х в первом случае принял значение месяца (добавил столбец столбец со значением месяца для этой задачи), во втором случае - проделал ту же процедуру - добавил столбец со значением недели и назначил на ось х.
#
#    Я не стал приводить к одной сетки значение оси у, так как это сделало бы график менее читаемым. Надеюсь, это не будет критическим замечанием, но если что - могу поправить. Также я добавил небольшой вывод.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Видим динамику расходов. TipTop и FaceBoom заметно выделяются.
#
# Не критично.
# </div>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

ax1.plot(
    costs.pivot_table(
    index='month',
    columns='channel',  
    values='costs',  
    aggfunc='sum',  
))
ax1.set_title('Распределение затрат на рекламу по месяцам')
ax1.set_ylabel('Затраты')
ax1.set_xlabel('Порядковый номер месяца')

ax2.plot(
    costs.pivot_table(
    index='week',
    columns='channel',  
    values='costs',  
    aggfunc='sum',  
))
ax2.set_title('Распределение затрат на рекламу по неделям')
ax2.set_ylabel('Затраты')
ax2.set_xlabel('Порядковый номер недели')

plt.show()

# %% [markdown]
# Вывод - расходы на рекламу постоянно растут. Пик расходов наблюдается в сентябре. За рост расходов ответственны два основных канала - TipTop и FaceBoom - по другим каналам значимого роста расходов не обнаружено.

# %% [markdown]
# #### Анализ стоимости привлечения пользователя (CAC)

# %%
cost_per_user = profiles.groupby('channel').agg({'acquisition_cost': 'mean'})\
.sort_values(by='acquisition_cost', ascending=False).reset_index()
cost_per_user
# Out:
#                channel  acquisition_cost
# 0               TipTop          2.799003
# 1             FaceBoom          1.113286
# 2           AdNonSense          1.008054
# 3       lambdaMediaAds          0.724802
# 4       WahooNetBanner          0.602245
# 5       RocketSuperAds          0.412095
# 6   OppleCreativeMedia          0.250000
# 7              YRabbit          0.218975
# 8         MediaTornado          0.218717
# 9              LeapBob          0.210172
# 10             organic          0.000000

# %%
sns.barplot(data=cost_per_user, x="channel", y='acquisition_cost')
plt.show()

# %%
profiles.pivot_table(    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
                    ).plot(grid=True, figsize=(20, 10))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Изменение САС с течением времени')
plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.show()

# %% [markdown]
# Вывод: Лидером по стоимости привлечения пользователя является TipTop. CAС. На графике заметна "лестница" повышения CAC. Вероятнее всего площадка несколько раз за год поднимала цену на рекламу - это отразилось на скачках на графике.
# Стоимость привлечения по другим каналам является стабильной за исключением снижения затрат на канале RocketSuperAds.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ И обходятся популярные каналы дороже.
#
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Можно еще рассчитать средний CAC на одного пользователя для всего проекта, так увидим на сколько выше среднего САС у популярных каналов.
#
# </div>

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %%
profiles = profiles.query('channel != "organic"') #исключаем пользователей, для привлечения которых не понадобилась реклама
observation_date = datetime(2019, 11, 1).date()  # задаём момент анализа согласно условию
horizon_days = 14  #задаём горизонт анализа согласно условию

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Правильно, что убираем из расчетов  пользователей с органическим трафиком, ведь мы за них ничего не платим.
# </div>

# %% [markdown]
# Теперь применим к таблицам функции, подготовленные в разделе 2

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon_days)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Выводы:
#
# На графике LTV видно, что средняя LTV всех пользователей к 14 дню приближается к 1$
#
# Из графика динамики LTV видно, что за последние 6 месяцев LTV не притерпела серьезных измений и колеблется в районе 1 доллара.
#
# Чего нельзя сказать о стоимости привлечения пользователей, которая стартовала с 0.7 доллара за одного пользователя в мае и увеличилась до 1.3 доллара за пользователя к концу октября
#
# Из графика ROI видно, что на 14й день пользователи не достигают порога окупаемости
#
# Из графика динамики ROI видно, что проблемы начались в июне (что коррелирует с повышением цены на привлечение пользователей в TipTop)

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Да, наблюдаем явные проблемы.
# </div>

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей на 14й день достигает 8%. Эта цифра в среднем сохраняется на протяжении всего исследуемого периода, хотя она и подвержена флуктуациям.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, sessions, observation_date, horizon_days)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вывод: Удержание платящих пользователей на 14й день держится в коридоре от 7.5 процентов до 17.5 процентов. Ближе к концу исследуемого периода оно стремится к нижней границе этого коридора.

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# По типу устройства пользователей можно разделить на две группы - пользователи продукции компании Apple - IPhone и Mac - и пользователи ПК и Android.
#
# У первой группы чуть выше LTV, но зато и CAC заметно превосходит затраты на привлечение пользователей второй групп.
# Как следствие - низкие показатели ROI у "яблочных" устройств. Из всех платформ на самоокупаемость к 14-му дню выходить только ПК.
#
# Если смотерть ROI в динамике, то заметен нисходящий тренд. Три платформы, за исключением ПК провалились ниже черты окупаемости к концу июня, а к сентябрю к ним присоединился и ПК.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Верно, за 14 дней окупается только PC. Но в динамике видим, что и он с сентября перестает окупаться.
# </div>

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Вывод: пользователи яблочных устройств в целом конвертируются лучше, чем ПК и Android. ПК сильно отстает от всех остальных платформ в плане конверсии - необходимо над этим поработать.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, sessions, observation_date, horizon_days, dimensions=dimensions)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Платящие пользователи ПК показывают хорошие показатели удержания. В целом, ПК выглядит перспективной платформой для инвестиций в рекламу.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ И тут PC выделяется.
# </div>

# %%
dimensions = ['region']
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# Пользователи из США, хотя и имеют самую большую LTV, не окупаются, потому что затраты на их привлечение превышают затраты на привлечение других пользователей почти в 5 раз!
# Последний раз, когда привлечение пользователей из США было обосновано - начало июня (до повышения цен на привлечение в TipTop)

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Согласен, можно еще изучить рекламу в США отдельно.
# </div>

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей из США в два раза выше, чем в Европе. Но этого все равно недостаточно, чтобы окупить пятикратные затраты на привлечение. Необходимо поработать над увеличением конверсии в Европе.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ В США конверсия заметно выше.
# </div>

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, sessions, observation_date, horizon_days, dimensions=dimensions)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Вывод: Пользователи из Европы знают цену своим деньгам. Они менее охотно платят за приложение (показатели конверсии в два раза ниже США), но если заплатили - остаются до конца. В то время как американцы готовы раскошелиться, но это не удерживает их от того, чтобы забросить приложение. Необходимо поработать над удержанием пользователей из США.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Еще одну проблему в США обнаружили.
# </div>

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Какие выводы можем сделать из графиков по каналам? После каждого построение графиков пишем выводы по ним, не стоит заставлять заказчика самостоятельно придумывать.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#    Расшифровка графиков добавлена ниже
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Определили проблемные каналы!
# </div>

# %% [markdown]
# Графики LTV показывают, что в абсолютном выражении больше всего денег платят клиенты, привлеченные через каналы lambdaMediaAds и TipTop
#
# В то же время, график динамики привлечения пользователей наглядно показывает постепенный рост стоимости привлечения пользователей по каналу TipTop
#
# По графику ROI на 14й день видно, что ниже черты окупаемости находятся пользователи, привлеченные через три источника - TipTop, AdNonSense и FaceBoom. Самые низкие показатели окупаемости у пользователей из TipTop. Это связано с огромными затратами на их привлечение.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions)
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   добавлена расшифровка
#
# </div>

# %% [markdown]
# На графике по конверсии заметно, что по ней лидируют те каналы, на которые тратятся больше всего средств. Топ-4 канала по конверсии и топ-4 канала по стоимости затрат на привлечение пользователя совпадают. Это говорит о том, что как правило, конверсию можно поднять, запустив рекламную компанию. Чего нельзя сказать об окупаемости.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, sessions, observation_date, horizon_days, dimensions=dimensions)
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# FaceBoom и AdNonSense показывают отличную конверсию, но ужасное удержание. В первую очередь необходимо выяснить, есть ли какая-то техническая проблема? В чем причина подобного поведения?
# Если технической проблемы нет, необходимо поработать над удержанием данных пользователей.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Видим причину не окупаемости каналов FaceBoom и AdNonSense.
# </div>

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# Основная причина неэффективности рекламы - рост CAC на всем протяжении периода исследования. Так как от CAC зависит ROI, увеличение стоимости привлечения пользователя резко отражается на окупаемости приложения.
#
# На основании графика о динамике изменения CAC можно сделать вывод о росте затрат на привлечение через канал **TipTop**.
# Вероятно, имело место увеличение стоимости услуг. Деньги, потраченные после увеличения стоимости услуг, не окупились.
#
# На основании графика об удержании можно сделать вывод, что есть огромные проблемы с удержанием пользователей, привлеченных через каналы **AdNonSense и FaceBoom**. Технической команде необходимо проверить данные каналы на наличие технических неисправностей или выявить другую причину, которая вызвала столь резко отличие в удержании пользователей, привлеченных через данные каналы, от остальных.
#
# **Привлечение пользователей из США необосновано дорогое (оно растет параллельно с ростом стоимости привлечения пользователей через TipTop), а удержание пользователей из данного региона - худшее из всех. При текущей динамике роста цены на привлечение инвестиции в рекламу в США необоснованы**
#
# **ПК является недооценной платформой. Пользователи ПК показывают самые высокие показатели удержания, однако затраты на их привлечение самые низкие. У остальных устройств ситуация противоположная - выше затраты на рекламу (как следствие высокая конверсия) - зато удержание пользователей ниже, чем у ПК. Если затраты на привлечение выше, следует задуматься об удержании столь дорогостоящих пользователей.**

# %% [markdown]
# Рекомендации:
#
# Прекратить необоснованные траты на дорогую рекламу. В первую очередь на платформе TipTop.
#
# В США обратить внимание на удержание пользователей. Ввести "бонус лояльности" или "вознаграждение за ежедневный вход в приложение" или поручить отделу маркетинга разработать свою стратегию, чтобы увеличить показатели удержания в США.
#
# В Европе увеличить затраты на привлечение пользователей. Пользователи этого региона показывают хорошие показатели ROI. Это означает, что деньги не будут потрачены впустую.
#
# Попытаться увеличить конверсию на платформе ПК. Пользователи ПК имеют отличные показатели по ROI. Однако, компания делает упор на рекламу в TipTop, которым в основном пользуются пользователи других устроиств. Освободившиеся деньги можно потратить на рекламу в других каналах, подходящих для пользователей ПК, например, в баннерных сетях.
#
# Каналы для привлечения пользователей lambdaMediaAds, RocketSuperAds, YRabbit выглядят перспективно. Необходимо произвести исследование данных каналов на предмет наличия платежеспособной аудитории.

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ В этом проекте очень важно дать интерпретацию графикам и написать развернутые выводы.\
# Нам надо найти и указать причины плохой окупаемости рекламы:
# - реклама в США - проблемы такие-то
# - канал TipTop - увеличение САС
# - канал FaceBoom, AdNonSense - проблемы с удерданием
# - рассмотреть ситуацию с устройствами\
# и т.д.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошие  рекомендации, маркетологи оценят!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#    К выводу добавлено два абзаца. Дополнения выделены жирным шрифтом. Все перечисленные в комментарии проблемы разобраны в выводе.
#
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Вывод преобразился, теперь видно в чем проблемы.  👍
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#   <b>Чек-лист доработок</b>
#
#   📃 Добавить краткое описание проекта.
#
#   📃 Дооформить графики, вывести название графика и подписать оси.
#
#   📃 Визуализировать динамику изменения расходов на маркетинг во времени (по неделям и месяцам) по каждому источнику.
#
#   📃 Написать выводы по всем графикам в шаге анализа причин неудовлетворительной окупаемости рекламных затрат.
#
#   📃 Написать более развернутый общий вывод.
#
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
# Благодарю за все комментарии! Особенно полезно было про plt.show() - до этого я не понимал, почему в некоторых графиках появляется технический текст, а в некоторых - нет.
#
# **По чек-листу:**
#
# Краткое описание проекта добавлено
#
# Графикам добалены недостающие названия, оси подписаны.
#
# Добавлены графики динамики изменения расходов на маркетинг во времени (по неделям и месяцам) по каждому источнику с использованием subplot() Вывод дополнен.
#
# Написаны дополнительные выводы по графикам в шаге анализа причин неудовлетворительной окупаемости рекламных затрат.
#
# Общий вывод дополнен
#
# </div>
